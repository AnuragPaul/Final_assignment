# %% [markdown]
# <a href="https://colab.research.google.com/github/AnuragPaul/Final_assignment/blob/master/Last_edition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def Game_State(x,y,level):
     global variable
 
    
     if Game_dict[level]['Life']==0:
        print("You have reached to the end position")
        Game_denoter()
     else:
        pass

def Game_State_sign(x,y,level):
  Obstacle_list = Game_dict[level]['Obstacle_coordinates']
  Advantage_list = Game_dict[level]['Advantage_coordinates']
  Size = Game_dict[level]['Size']
  Remaining_life=Game_dict[level]['Life']
  Remaining_jump=Game_dict[level]['Jump']
  Number_of_obstacle=Game_dict[level]['Obstacle']
  Number_of_Advantage=Game_dict[level]['Advantage']
  Ending_Coordinate=[Size-1,Size-1]
  
  for i in range(0, Size):
    for j in range(0, Size):
      list_ij=[i,j]
      if (i==x and j==y):
        print("start",end='  ')
      elif (list_ij in Obstacle_list):
        print("*",end='  ')
      elif (list_ij in Advantage_list):
        print("+",end='  ')
      elif (i==9 and j==9):
        print("end",end='  ')
      else:
        print("-",end='  ')
    print('\n')

def Game_State_Coordinate(x,y,level):
  Obstacle_list = Game_dict[level]['Obstacle_coordinates']
  Advantage_list = Game_dict[level]['Advantage_coordinates']
  Size = Game_dict[level]['Size']
  for i in range(0, Size):
    for j in range(0, Size):
      list_ij=[i,j]
      if (i==x and j==y):
        print("\033[0;37;44m {:2.0f},".format(i),j,end='  ')
      elif (list_ij in Obstacle_list):
        print("\033[0;37;41m {:2.0f},".format(i),j,end='  ')
      elif (list_ij in Advantage_list):
        print("\033[0;37;42m {:2.0f},".format(i),j,end='  ')
      elif (i==9 and j==9):
        print("\033[0;37;45m {:2.0f},".format(i),j,end='  ')
      else:
        print("\033[0;30;47m {:2.0f},".format(i),j,end='  ')
    print('\n')
print("Enter Game state function to see your current position(ex:Game_State_sign(x,y,level))and similarly Game_State_coordinate")
# Out:
# Enter Game state function to see your current position(ex:Game_State_sign(x,y,level))and similarly Game_State_coordinate

# %%
def Move(x,y):
    global point
    
    global variable
    
    
    Obstacle_list = Game_dict[level]['Obstacle_coordinates']
    Advantage_list = Game_dict[level]['Advantage_coordinates']
    A=int(input())
    if A==2:
      Present_Coordinate=[x+1,y]
      print(Present_Coordinate)
      if Present_Coordinate[0]<0 or Present_Coordinate[0]>Game_dict[level]['Size']-1 or Present_Coordinate[1]<0 or Present_Coordinate[1]>Game_dict[level]['Size']-1:
        print("You are out of boundary")
        print("Go back to your past position by undo function")
        variable=variable-1
        print(f"Your remaining life is {variable}")

      if Present_Coordinate in Game_dict[level]['Obstacle_coordinates']:
        print("OOps!You have touched obstacle")
        point=point-5
        print(f"Your obtained point till now is{point}")
      elif Present_Coordinate in  Game_dict[level]['Advantage_coordinates']:
        print("Wow!You have touched advantage")
        point=point+10
        print(f"Your obtained point till now is{point}")
      elif Present_Coordinate==[Game_dict[level]['Size']-1,Game_dict[level]['Size']-1]:
        print("You have reached the end position")
        print(point)
        Game_denoter()
      else:
        print("Please go on")
    
    elif A==8:
      Present_Coordinate=[x-1,y]
      print(Present_Coordinate)
      if Present_Coordinate[0]<0 or Present_Coordinate[0]>Game_dict[level]['Size']-1 or Present_Coordinate[1]<0 or Present_Coordinate[1]>Game_dict[level]['Size']-1:
        print("You are out of boundary")
        print("Go back to your past position by undo function")
        variable=variable-1
        print(f"Your remaining life is {variable}")
      if Present_Coordinate in Game_dict[level]['Obstacle_coordinates']:
        print("OOps!You have touched obstacle")
        point=point-5
        print(f"Your obtained point till now is{point}")
      elif Present_Coordinate in  Game_dict[level]['Advantage_coordinates']:
        print("Wow!You have touched advantage")
        point=point+10
        print(f"Your obtained point till now is{point}")
      elif Present_Coordinate==[Game_dict[level]['Size']-1,Game_dict[level]['Size']-1]:
        print("You have reached the end position")
        print(f"Your obtained point is{point}")
        Game_denoter()
      else:
        print("Please go on")

      
    elif A==4:
      Present_Coordinate=[x,y-1]
      print(Present_Coordinate)
      if Present_Coordinate[0]<0 or Present_Coordinate[0]>Game_dict[level]['Size']-1 or Present_Coordinate[1]<0 or Present_Coordinate[1]>Game_dict[level]['Size']-1:
        print("You are out of boundary")
        print("Go back to your past position by undo function")
        variable=variable-1
        print(f"Your remaining life is {variable}")
        
      if Present_Coordinate in Game_dict[level]['Obstacle_coordinates']:
        print("OOps!You have touched obstacle")
        point=point-5
        print(f"Your obtained point till now is{point}")
      elif Present_Coordinate in  Game_dict[level]['Advantage_coordinates']:
        print("Wow!You have touched advantage")
        point=point+10
        print(f"Your obtained point till now is{point}")
      elif Present_Coordinate==[Game_dict[level]['Size']-1,Game_dict[level]['Size']-1]:
        print("You have reached the end position")
        print(f"Your obtained point is{point}")
        Game_denoter()
      else:
        print("Please go on")
      
    elif A==6:
      Present_Coordinate=[x,y+1]
      print(Present_Coordinate)
      if Present_Coordinate[0]<0 or Present_Coordinate[0]>Game_dict[level]['Size']-1 or Present_Coordinate[1]<0 or Present_Coordinate[1]>Game_dict[level]['Size']-1:
        print("You are out of boundary")
        print("Go back to your past position by undo function")
        variable=variable-1
        print(f"Your remaining life is {variable}")
      if Present_Coordinate in Game_dict[level]['Obstacle_coordinates']:
        print("OOps!You have touched obstacle")
        point=point-5
        print(f"Your obtained point till now is{point}")
      elif Present_Coordinate in  Game_dict[level]['Advantage_coordinates']:
        print("Wow!You have touched advantage")
        point+=10
        print(f"Your obtained point till now is{point}")
      elif Present_Coordinate==[Game_dict[level]['Size']-1,Game_dict[level]['Size']-1]:
        print("You have reached the end position")
        print(f"Your obtained point is{point}")
        Game_denoter()
      else:
        print("Please go on")

# %%
 def jump(f,l):
    global point
    global variable
    a=int(input("Enter 5 for initializing jump "))
    b=int(input("Enter 2 to jump down or 8 to jum up or 4 to jump left or 6 to jump right"))
    if a==5 and b==2:
              Present_Coordinate=[f+2,l]
              print(Present_Coordinate)
              if Present_Coordinate[0]<0 or Present_Coordinate[0]>Game_dict[level]['Size']-1 or Present_Coordinate[1]<0 or Present_Coordinate[1]>Game_dict[level]['Size']-1:
                print("You are out of boundary")
                print("Go back to your past position by undo function")
                variable=variable-1
                print(f"Your remaining life is {variable}")
              Game_dict[level]['Jump']=Game_dict[level]['Jump']-1
              print(f"Your remaining jump number is {Game_dict[level]['Jump']}")
              if Present_Coordinate in Game_dict[level]['Obstacle_coordinates']:
                  print("OOps!You have touched obstacle")
                  point=point-5
                  print(f"Your obtained point till now is{point}")
              elif Present_Coordinate in  Game_dict[level]['Advantage_coordinates']:
                    print("Wow!You have touched advantage")
                    point+=10
                    print(f"Your obtained point till now is{point}")
              elif Present_Coordinate==[Game_dict[level]['Size']-1,Game_dict[level]['Size']-1]:
                    print("You have reached the end position")
                    Game_denoter()
              else:
                    print("Please go on")
    elif a==5 and b==8:
                Present_Coordinate=[f-2,l]
                print(Present_Coordinate)
                if Present_Coordinate[0]<0 or Present_Coordinate[0]>Game_dict[level]['Size']-1 or Present_Coordinate[1]<0 or Present_Coordinate[1]>Game_dict[level]['Size']-1:
                    print("You are out of boundary")
                    print("Go back to your past position by undo function")
                    variable=variable-1
                    print(f"Your remaining life is {variable}")
                if Present_Coordinate in Game_dict[level]['Obstacle_coordinates']:
                    print("OOps!You have touched obstacle")
                    point=point-5
                    print(f"Your obtained point till now is{point}")
                elif Present_Coordinate in  Game_dict[level]['Advantage_coordinates']:
                    print("Wow!You have touched advantage")
                    point=point+10
                    print(f"Your obtained point till now is{point}")
                elif Present_Coordinate==[Game_dict[level]['Size']-1,Game_dict[level]['Size']-1]:
                    print("You have reached the end position")
                    Game_denoter()
                else:
                    print("Please go on")
    elif a==5 and b==4:
                Present_Coordinate=[f,l-2]
                print(Present_Coordinate)
                if Present_Coordinate[0]<0 or Present_Coordinate[0]>Game_dict[level]['Size']-1 or Present_Coordinate[1]<0 or Present_Coordinate[1]>Game_dict[level]['Size']-1:
                    print("You are out of boundary")
                    print("Go back to your past position by undo function")
                    variable=variable-1
                    print(f"Your remaining life is {variable}")
                if Present_Coordinate in Game_dict[level]['Obstacle_coordinates']:
                    print("OOps!You have touched obstacle")
                    point=point-5
                    print(f"Your obtained point till now is{point}")
                elif Present_Coordinate in  Game_dict[level]['Advantage_coordinates']:
                    print("Wow!You have touched advantage")
                    point+=10
                    print(f"Your obtained point till now is{point}")
                elif Present_Coordinate==[Game_dict[level]['Size']-1,Game_dict[level]['Size']-1]:
                    print("You have reached the end position")
                    Game_denoter()
                else:
                    print("Please go on")
    elif a==5 and b==6:
                  Present_Coordinate=[f,l+2]
                  print(Present_Coordinate)
                  if Present_Coordinate[0]<0 or Present_Coordinate[0]>Game_dict[level]['Size']-1 or Present_Coordinate[1]<0 or Present_Coordinate[1]>Game_dict[level]['Size']-1:
                      print("You are out of boundary")
                      print("Go back to your past position by undo function")
                      variable=variable-1
                      print(f"Your remaining life is {variable}")
                  if Present_Coordinate in Game_dict[level]['Obstacle_coordinates']:
                      print("OOps!You have touched obstacle")
                      point=point-5
                      print(f"Your obtained point till now is{point}")
                  elif Present_Coordinate in  Game_dict[level]['Advantage_coordinates']:
                      print("Wow!You have touched advantage")
                      point+=10 
                      print(f"Your obtained point till now is{point}")
                  elif Present_Coordinate==[Game_dict[level]['Size']-1,Game_dict[level]['Size']-1]:
                      print("You have reached the end position")
                      Game_denoter()
                  else:
                      print("Please go on")

# %%
def Game_denoter():

    while(True):
          if Game_dict[level]['Life']==0:
            print(f"You have lost with point{point} ")
            break
          elif  Present_Coordinate==[Game_dict[level]['Size']-1,Game_dict[level]['Size']-1]:
            print(f"You have won with point{point}")
            break
          else:
            print("You can continue your game")
            break

# %%
print("Welcome to 'Memorize your move' game!")
print("Rules of games: 1. You will lose one life for going out of bound...")
print("How to play: Press 8 for going up, ...... 5 for jump then ..... type game state function (example:(game_state(x,y,'level'))for showing game state")
print("Choose your level: .....")
level=input()

print(f"In this level you will get {Game_dict[level]['Life']} lives .....")
print("Memorize your present coordinate and obstacles ......")
print("Start making moves..")
print("You can use move function from your starting position to go ahead(Example:Move(1,2)------->pressing 6(right)====>(1,3)")
print("You can use jump function from your starting position to go ahead(Example:jump(1,2)------->pressing 6(right)====>(1,4)")
print("You have to use undo function when you are out of bound(Example:undo(4,6)----->Your Current Position is again [4, 6]")
# Out:
# Welcome to 'Memorize your move' game!
# Rules of games: 1. You will lose one life for going out of bound...
# How to play: Press 8 for going up, ...... 5 for jump then ..... type game state function (example:(game_state(x,y,'level'))for showing game state
# Choose your level: .....
# Easy
# In this level you will get 5 lives .....
# Memorize your present coordinate and obstacles ......
# Start making moves..
# You can use move function from your starting position to go ahead(Example:Move(1,2)------->pressing 6(right)====>(1,3)
# You can use jump function from your starting position to go ahead(Example:jump(1,2)------->pressing 6(right)====>(1,4)
# You have to use undo function when you are out of bound(Example:undo(4,6)----->Your Current Position is again [4, 6]

# %%
#I haven't use random coordinate for advantage coordinates because There may have crash or similarity between advantage coordinates and obstacle coordinates.
Game_dict = {'Easy': {'Size': 10, 'Life': 5, 'Jump': 5, 'Obstacle': 10, 'Advantage': 20,
                      'Obstacle_coordinates':'[]',

                      'Advantage_coordinates': [[5, 6], [7, 2], [7, 4], [1, 0], [6, 5], [1, 0], [2, 4], [6, 6], [2, 3],
                                                [4, 9],
                                                [3, 2], [0, 9], [0, 7], [1, 5], [7, 0], [9, 5], [4, 4], [3, 8], [3, 5],
                                                [5, 3]]},

             'Medium': {'Size': 20, 'Life': 8, 'Jump': 10, 'Obstacle': 15, 'Advantage': 25,
                        'Obstacle_coordinates':'[]',

                        'Advantage_coordinates': [[8, 8], [13, 15], [2, 8], [2, 12], [1, 4], [13, 5], [6, 3], [8, 5],
                                                  [15, 12], [14, 7], [2, 5], [9, 13], [5, 10],
                                                  [15, 8], [1, 4], [15, 11], [9, 12], [3, 11], [5, 14], [6, 13],
                                                  [14, 16], [8, 3], [4, 17], [10, 11], [7, 11]]},

             'Hard': {'Size': 25, 'Life': 10, 'Jump': 15, 'Obstacls': 20, 'Advantage': 35,
                      'Obstacle_coordinates':'[]',

                      'Advantage_coordinates': [[2, 16], [6, 17], [9, 12], [18, 18], [12, 6], [4, 2], [1, 1], [18, 12],
                                                [11, 14], [12, 9], [17, 2], [19, 0], [16, 13], [0, 7],
                                                [12, 0], [8, 15], [11, 3], [4, 16], [13, 16], [5, 19], [9, 1], [6, 18],
                                                [8, 7], [7, 17], [3, 1], [6, 18], [12, 1], [19, 1], [5, 2],
                                                [9, 3], [9, 19], [16, 12], [3, 13], [3, 13], [5, 2]]}}
from random import randint
First_List=[]
Last_List=[]
print("Enter your game level:")
New_List=[]
level=input()
while(1):
    if level == 'Easy':

        for j in range(5):
            First_List.append(randint(0, 9))

        for j in range(2):
            Last_List.append(randint(0, 9))

        for i in First_List:
            for j in Last_List:
                List = [i, j]
                j = j + 1
                i = i + 1
                New_List.append(List)
    Game_dict[level]['Obstacle_coordinates'] = New_List
    print(Game_dict)
    break
    if level == 'Medium':
        for j in range(5):
            First_List.append(randint(0, 9))

        for j in range(3):
            Last_List.append(randint(0, 9))

        for i in First_List:
            for j in Last_List:
                List = [i, j]
                j = j + 1
                i = i + 1
                New_List.append(List)
    Game_dict[level]['Obstacle_coordinates'] = New_List
    print(Game_dict)
    break
    if level == 'Hard':
         for j in range(4):
             First_List.append(randint(0, 9))

         for j in range(5):
            Last_List.append(randint(0, 9))

         for i in First_List:
             for j in Last_List:
                 List = [i, j]
                 j = j + 1
                 i = i + 1
                 New_List.append(List)
    Game_dict[level]['Obstacle_coordinates'] = New_List
    print(Game_dict)
    break

# %%
def undo(x,y):
  print("Your Current Position is again",[x,y])
